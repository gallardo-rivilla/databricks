# %% [markdown]
# # Ejemplo Particionado de Datos

# %%
import analytics.general_utils as gen_utils
import time
import pyspark.sql.functions as F
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Sin Particionar

# %%
# (spark
#  .read
#  .parquet("/mnt/analytics/test_particionado/fp_001_part")
#  .repartition(44*58)
#  .write
#  .parquet("/mnt/analytics/test_particionado/fp_001_no_part_def"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Leemos tabla inicial sin particionar. Contiene datos de 44 particiones

fp_001 = (spark.read.parquet("/mnt/analytics/test_particionado/fp_001_no_part_def"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %%timeit -n 3 -r 1

# Vemos lo que tarda en hacer un count & distinct sin ningún filtro
(fp_001
 .distinct()
 .count())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">3 loops, best of 1: 1min 4s per loop
# </div>

# %%
# %%timeit -n 3 -r 1

# Vemos lo que tarda en hacer un count & distinct filtrando por una partición
(fp_001
 .filter(F.col("periodo") == 20200610)
 .distinct()
 .count())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">3 loops, best of 1: 33.9 s per loop
# </div>

# %% [markdown]
# ## Particionado por periodo: PARQUET

# %%
# Escribimos, pero particionando por periodo

# (fp_001
#  .write
#  .mode("OVERWRITE")
#  .partitionBy("periodo")
#  .parquet("/mnt/analytics/test_particionado/fp_001_part"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Leemos tabla particionada, todas las particiones

fp_001_all_parts = (spark
                   .read
                   .parquet("/mnt/analytics/test_particionado/fp_001_part"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %%timeit -n 3 -r 1

# Vemos lo que tarda en hacer un count & distinct sin ningún filtro (antes 1m 4s)
(fp_001_all_parts
 .distinct()
 .count())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">3 loops, best of 1: 49.3 s per loop
# </div>

# %%
# %%timeit -n 3 -r 1

# Vemos lo que tarda en hacer un count & distinct filtrando por una partición (antes 33.9s)
(fp_001_all_parts
 .filter(F.col("periodo") == 20200610)
 .distinct()
 .count())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">3 loops, best of 1: 2.44 s per loop
# </div>

# %%
# Leemos de manera individual una única partición

fp_001_20200610 = (spark
                   .read
                   .parquet("/mnt/analytics/test_particionado/fp_001_part/periodo=20200610"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %%timeit -n 3 -r 1

# Vemos lo que tarda en hacer un count & distinct "filtrando por una partición" (antes 2.44s)

(fp_001_20200610
 .distinct()
 .count())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">3 loops, best of 1: 2.42 s per loop
# </div>

# %% [markdown]
# # Particionado por periodo: DELTA

# %%
# Escribimos en formato delta particionado por periodo

# (fp_001
#  .write
#  .format("DELTA")
#  .mode("OVERWRITE")
#  .partitionBy("periodo")
#  .save("/mnt/analytics/test_particionado/fp_001_part_delta"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Leemos tabla en formato Delta

fp_001_all_parts_delta = (spark
                          .read
                          .format("delta")
                          .load("/mnt/analytics/test_particionado/fp_001_part_delta"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %%timeit -n 3 -r 1

# Vemos lo que tarda en hacer un count & distinct filtrando por una partición (antes 2.44s)
(fp_001_all_parts_delta
 .filter(F.col("periodo") == 20200610)
 .distinct()
 .count())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">3 loops, best of 1: 2.72 s per loop
# </div>

# %% [markdown]
# # Varios niveles de particionado & DELTA OPTIMIZE

# %%
# Escribimos en formato delta particionado por periodo y racepint

(fp_001
 .write
 .format("DELTA")
 .mode("OVERWRITE")
 .partitionBy(["periodo", "racepint"])
 .save("/mnt/analytics/test_particionado/fp_001_part_delta_2"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Query para la optimización de la escritura de la tabla

# %sql
# OPTIMIZE delta.`/mnt/analytics/test_particionado/fp_001_part_delta_2`

# %%
# Leemos tabla en formato delta con doble partición

fp_001_all_parts_delta_2 = (spark
                          .read
                          .format("delta")
                          .load("/mnt/analytics/test_particionado/fp_001_part_delta_2"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %%timeit -n 10 -r 1

# Vemos lo que tardaba con una partición un conteo & distinct aplicando 2 filtros

(fp_001_all_parts_delta
 .filter((F.col("periodo") == 20200610) & 
         (F.col("racepint") == "S"))
 .distinct()
 .count())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">10 loops, best of 1: 3.05 s per loop
# </div>

# %%
# %%timeit -n 10 -r 1

# Vemos lo que tarda ahora con doble partición un conteo & distinct aplicando 2 filtros
(fp_001_all_parts_delta_2
 .filter((F.col("periodo") == 20200610) & 
         (F.col("racepint") == "S"))
 .distinct()
 .count())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">10 loops, best of 1: 1.05 s per loop
# </div>

# %% [markdown]
# # Sobreescritura de particiones

# %% [markdown]
# ## Utilizando Delta Lake

# %%
# Sacamos primero el conteo de la partición original que queremos sustituir

(fp_001_all_parts_delta_2
 .filter(F.col("periodo") == 20200501)
 .count())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">303</span><span class="ansired">]: </span>4409136</div>

# %%
# Conteo de la tabla total

(fp_001_all_parts_delta_2.count())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">304</span><span class="ansired">]: </span>194027547</div>

# %%
# Obtenemos datos nuevos para la partición 20200501

new_part_20200501 = (spark
                     .read
                     .parquet("/mnt/analytics/test_particionado/fp_001_part/periodo=20200501")
                     .sample(0.01)
                     .withColumn("periodo", F.lit("20200501").cast("int")))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
new_part_20200501.cache()
new_part_20200501.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">306</span><span class="ansired">]: </span>44478</div>

# %%
# Sobreescribimos los datos únicamente de la partición 20200501, conservando el esquema y 
# el particionado inicial

(new_part_20200501
 .write
 .format("DELTA")
 .mode("OVERWRITE")
 .option("replaceWhere", "periodo = 20200501")
 .option("mergeSchema", "true")
 .save("/mnt/analytics/test_particionado/fp_001_part_delta_2"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Leemos nueva tabla

fp_001_all_parts_delta_2_new = (spark
                                .read
                                .format("DELTA")
                                .load("/mnt/analytics/test_particionado/fp_001_part_delta_2"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# 194027547, 4409136, 44478
print("Conteo inicial de la tabla: 194027547")
print("Conteo de la partición original de la tabla: 4409136")
print("Conteo de la partición nueva de la tabla: 44478")
print("Conteo de la tabla modificada: {0}".format(194027547-4409136+44478))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Conteo inicial de la tabla: 194027547
# Conteo de la partición original de la tabla: 4409136
# Conteo de la partición nueva de la tabla: 44478
# Conteo de la tabla modificada: 189662889
# </div>

# %%
# Conteo de la nueva partición

(fp_001_all_parts_delta_2_new
 .filter(F.col("periodo") == 20200501)
 .count())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">311</span><span class="ansired">]: </span>44478</div>

# %%
# Conteo de la tabla final

fp_001_all_parts_delta_2_new.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">313</span><span class="ansired">]: </span>189662889</div>

# %%
# Añadimos una nueva partición 20210501 con los datos de la anterior
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Añadimos una nueva partición 20210501 con los datos de la anterior
# Creamos datos de prueba

new_part_20210501 = (spark
                     .read
                     .parquet("/mnt/analytics/test_particionado/fp_001_part/periodo=20200501")
                     .sample(0.01)
                     .withColumn("periodo", F.lit("20210501").cast("int")))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
new_part_20210501.cache()
new_part_20210501.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">322</span><span class="ansired">]: </span>43933</div>

# %%
# Escribmos datos sobre una partición inexistente

(new_part_20210501
 .write
 .format("DELTA")
 .mode("OVERWRITE")
 .option("replaceWhere", "periodo = 20210501")
 .option("mergeSchema", "true")
 .save("/mnt/analytics/test_particionado/fp_001_part_delta_2"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Leemos nueva tabla

fp_001_all_parts_delta_2_new = (spark
                                .read
                                .format("DELTA")
                                .load("/mnt/analytics/test_particionado/fp_001_part_delta_2"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
(fp_001_all_parts_delta_2_new
 .filter(F.col("periodo") == 20210501)
 .count())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">325</span><span class="ansired">]: </span>43933</div>

# %%
print("El conteo de la nueva tabla debería de ser: {0}".format(189662889+43933))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">El conteo de la nueva tabla debería de ser: 189706822
# </div>

# %%
fp_001_all_parts_delta_2_new.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">326</span><span class="ansired">]: </span>189706822</div>

# %% [markdown]
# ## Utilizando formato Parquet convencional

# %%
# A continuación se escribe como sería realizar la misma operación del apartado anterior pero utilizando formato 
# parquet convencional


# (new_part_20200501
#  .filter(F.col("racepint")=="N")
#  .drop("periodo", "racepint")
#  .write
#  .parquet("/mnt/analytics/test_particionado/fp_001_part/periodo=20200501/racepint==N"))


# (new_part_20200501
#  .filter(F.col("racepint")=="S")
#  .drop("periodo", "racepint")
#  .write
#  .parquet("/mnt/analytics/test_particionado/fp_001_part/periodo=20200501/racepint==S))

# %% [markdown]
# # Escritura de nuevas particiones y sobre-escritura de antiguas con un mismo ccomando

# %%
# Creamos datos para la partición: 20210501

new_part_20210501 = (spark
                     .read
                     .parquet("/mnt/analytics/test_particionado/fp_001_part/periodo=20200501")
                     .sample(0.01)
                     .withColumn("periodo", F.lit("20210501").cast("int")))

new_part_20210501.cache()
new_part_20210501.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">330</span><span class="ansired">]: </span>44234</div>

# %%
# Creamos datos para la partición: 20220501

new_part_20220501 = (spark
                     .read
                     .parquet("/mnt/analytics/test_particionado/fp_001_part/periodo=20200501")
                     .sample(0.02)
                     .withColumn("periodo", F.lit("20220501").cast("int")))

new_part_20220501.cache()
new_part_20220501.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">331</span><span class="ansired">]: </span>87714</div>

# %%
# Persistimos partición 20210501

(new_part_20210501
 .write
 .format("DELTA")
 .mode("OVERWRITE")
 .option("replaceWhere", "periodo = 20210501")
 .partitionBy(["periodo", "racepint"])
 .save("/mnt/analytics/test_particionado/fp_001_part_delta_3"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Persistimos partición 20220501

(new_part_20220501
 .write
 .format("DELTA")
 .mode("OVERWRITE")
 .option("replaceWhere", "periodo = 20220501")
 .partitionBy(["periodo", "racepint"])
 .save("/mnt/analytics/test_particionado/fp_001_part_delta_3"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Leemos nueva tabla

fp_001_part_delta_3 = (spark
                       .read
                       .format("DELTA")
                       .load("/mnt/analytics/test_particionado/fp_001_part_delta_3"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Comprobamos conteos

(fp_001_part_delta_3
 .groupBy("periodo")
 .count()
 .show())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------+-----+
#  periodo|count|
# +--------+-----+
# 20210501|43933|
# 20220501|87714|
# +--------+-----+
#
# </div>

# %%
# Nuevos datos para la partición 20220501

new_part_20220501 = (spark
                     .read
                     .parquet("/mnt/analytics/test_particionado/fp_001_part/periodo=20200501")
                     .sample(0.05)
                     .withColumn("periodo", F.lit("20220501").cast("int")))

new_part_20220501.cache()
new_part_20220501.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">337</span><span class="ansired">]: </span>221178</div>

# %%
# Sustituimos partición 20220501

(new_part_20220501
 .write
 .format("DELTA")
 .mode("OVERWRITE")
 .option("replaceWhere", "periodo = 20220501")
 .partitionBy(["periodo", "racepint"])
 .save("/mnt/analytics/test_particionado/fp_001_part_delta_3"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
fp_001_part_delta_3 = (spark
                       .read
                       .format("DELTA")
                       .load("/mnt/analytics/test_particionado/fp_001_part_delta_3"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Comproabmos conteos

(fp_001_part_delta_3
 .groupBy("periodo")
 .count()
 .show())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------+------+
#  periodo| count|
# +--------+------+
# 20210501| 43933|
# 20220501|221178|
# +--------+------+
#
# </div>

# %% [markdown]
# # Conclusiones finales
#
# Se recomienda utilizar formato `DELTA` con varios niveles de particionado

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# periodo
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
df
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# COMANDO BASE

path_table = ""

(df # df es la tabla
 .write
 .format("DELTA")
 .mode("OVERWRITE")
 .option("replaceWhere", "periodo = {0}".format(periodo)) # periodo es el periodo de la ta
 .partitionBy(["periodo"])
 .save(path_table))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# COMANDO BASE

# (new_part_20220501
#  .write
#  .format("DELTA")
#  .mode("OVERWRITE")
#  .option("replaceWhere", "periodo = 20220501")
#  .partitionBy(["periodo", "racepint"])
#  .save("/mnt/analytics/test_particionado/fp_001_part_delta_3"))
